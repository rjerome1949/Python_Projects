# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import mean

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
housing_usd = pd.read_csv('/content/drive/MyDrive/housing_usd.csv')

# %%
housing_usd.head()
# Out:
#                                          Description  \
# 0  Preselling 2-Storey Townhouses in Village East...
# 1  Affordable House & Lot with Complete Amenities...
# 2  5BR 2-Storey House and Lot for Sale in Tarlac ...
# 3  Maya Solo 3 Bedrooms Single Detached House for...
# 4  Futura Homes Zamboanga | Amber 2BR Townhouse E...
#
#                                      Location      Price      Price_USD  \
# 0                       Santo Domingo, Cainta  9500000.0  168493.191988
# 1                    San Vicente, Santa Maria  4400000.0   78038.952079
# 2  Camella Tarlac Access Rd. Maliwalo, Tarlac  7810000.0  138519.139940
# 3                               Gabon, Abucay        NaN            NaN
# 4             Zambowood Rd. Boalan, Zamboanga  3275000.0   58085.810922
#
#    Bedrooms  Bathrooms  Floor Area  Land Area   Latitude   Longitude
# 0       4.0        3.0      144.00      136.0  14.582341  121.118044
# 1       3.0        2.0       63.20       80.0  14.807715  121.002402
# ...

# %%
housing_usd.drop(columns=['Latitude', 'Longitude'])
# Out:
#                                             Description  \
# 0     Preselling 2-Storey Townhouses in Village East...
# 1     Affordable House & Lot with Complete Amenities...
# 2     5BR 2-Storey House and Lot for Sale in Tarlac ...
# 3     Maya Solo 3 Bedrooms Single Detached House for...
# 4     Futura Homes Zamboanga | Amber 2BR Townhouse E...
# ...                                                 ...
# 1495  5 Bedroom House and Lot for sale in Asisan, Ta...
# 1496  For Sale: Affordable 3 Bedroom Townhouse at Se...
# 1497  Modern 4BR House with Swimming Pool in AFPOVAI...
# 1498  Modern House w/ Overlooking Mountain view in A...
# 1499  [04847-CEB-124] Townhouse for sale in Brgy Tuy...
#
#                                                Location       Price  \
# 0                                 Santo Domingo, Cainta   9500000.0
# 1                              San Vicente, Santa Maria   4400000.0
# 2            Camella Tarlac Access Rd. Maliwalo, Tarlac   7810000.0
# ...

# %%
housing_usd.drop(columns=['Latitude', 'Longitude'])
housing_usd.head()
# Out:
#                                          Description  \
# 0  Preselling 2-Storey Townhouses in Village East...
# 1  Affordable House & Lot with Complete Amenities...
# 2  5BR 2-Storey House and Lot for Sale in Tarlac ...
# 3  Maya Solo 3 Bedrooms Single Detached House for...
# 4  Futura Homes Zamboanga | Amber 2BR Townhouse E...
#
#                                      Location      Price      Price_USD  \
# 0                       Santo Domingo, Cainta  9500000.0  168493.191988
# 1                    San Vicente, Santa Maria  4400000.0   78038.952079
# 2  Camella Tarlac Access Rd. Maliwalo, Tarlac  7810000.0  138519.139940
# 3                               Gabon, Abucay        NaN            NaN
# 4             Zambowood Rd. Boalan, Zamboanga  3275000.0   58085.810922
#
#    Bedrooms  Bathrooms  Floor Area  Land Area   Latitude   Longitude
# 0       4.0        3.0      144.00      136.0  14.582341  121.118044
# 1       3.0        2.0       63.20       80.0  14.807715  121.002402
# ...

# %%
housing_usd.head()
# Out:
#                                          Description  \
# 0  Preselling 2-Storey Townhouses in Village East...
# 1  Affordable House & Lot with Complete Amenities...
# 2  5BR 2-Storey House and Lot for Sale in Tarlac ...
# 3  Maya Solo 3 Bedrooms Single Detached House for...
# 4  Futura Homes Zamboanga | Amber 2BR Townhouse E...
#
#                                      Location      Price      Price_USD  \
# 0                       Santo Domingo, Cainta  9500000.0  168493.191988
# 1                    San Vicente, Santa Maria  4400000.0   78038.952079
# 2  Camella Tarlac Access Rd. Maliwalo, Tarlac  7810000.0  138519.139940
# 3                               Gabon, Abucay        NaN            NaN
# 4             Zambowood Rd. Boalan, Zamboanga  3275000.0   58085.810922
#
#    Bedrooms  Bathrooms  Floor Area  Land Area   Latitude   Longitude
# 0       4.0        3.0      144.00      136.0  14.582341  121.118044
# 1       3.0        2.0       63.20       80.0  14.807715  121.002402
# ...

# %%
housing_usd.to_csv('housing_usd.csv', index=False)

# %%
import matplotlib.pyplot as plt
housing_usd.plot.scatter("Floor Area", 'Price_USD',s= 5, c= 'orange')
plt.title("Floor Area as a Predictor of Price")
plt.xlabel("Floor Area in Meters Squared")
plt.ylabel('Price in USD')
plt.show()

# %%
housing_usd["Price_USD"].plot.hist(bins=25, edgecolor = "k", alpha=0.7)
#plt.axvline(housing_usd['Price_USD'].mean(), color = "yellow", linestyle = 'dashed', linewidth = 1)
#plt.axvline(housing_usd['Price_USD'].median(), color = 'red', linestyle = 'dashed', linewidth = 1)
plt.title("Histogram of Real Estate Prices in USD")
plt.xlabel("Price in USD")
plt.show()
#counts, bin_edges = np.histogram(housing_usd, bins = 25)

# %%
 from scipy.stats import pearsonr

# %%
housing_usd['Price_USD'].corr(housing_usd['Floor Area'])
# Out:
# 0.6767441277340082

# %%
housing_usd['Price_USD'].corr(housing_usd['Bathrooms'])
# Out:
# 0.32650190403283996

# %%
housing_usd['Price_USD'].corr(housing_usd['Bedrooms'])
# Out:
# 0.2960106911630956

# %%
print("Range is", housing_usd.Price_USD.max()- housing_usd.Price_USD.min())
# Out:
# Range is 44334992.84347338

# %%
print("Minimum value of Price USD is",  housing_usd.Price_USD.min())
# Out:
# Minimum value of Price USD is 5320.837641733812

# %%
print("Maximum value of Price USD is",  housing_usd.Price_USD.max())
# Out:
# Maximum value of Price USD is 44340313.68111511

# %%
print("Mean value of Price USD is",  housing_usd.Price_USD.mean())
# Out:
# Mean value of Price USD is 582138.2293822543

# %%
print("Standard deviation of Price USD is",  housing_usd.Price_USD.std())
# Out:
# Standard deviation of Price USD is 1795695.7383136454

# %%
original_sample = housing_usd['Price_USD'].sample(frac=0.1, replace = True, random_state=123)

# %%
original_sample.head()
# Out:
# 1389    1.206057e+05
# 1406    7.360492e+04
# 1346    2.305696e+05
# 1122    1.454362e+05
# 1041    1.330209e+06
# Name: Price_USD, dtype: float64

# %%
print("Median value of Price USD is",  original_sample.median())
# Out:
# Median value of Price USD is 137543.65303881906

# %%
print("Mean value of the medians is",  original_sample.mean())
# Out:
# Mean value of the medians is 598484.3794904257

# %%
median_boot_samples =[]
for i in range(1000):
  boot_sample = np.random.choice(original_sample, 100)
  median_boot_samples.append(np.median(boot_sample))
np.mean(median_boot_samples)
# Out:
# nan

# %%
print("Arithmetic Mean is :", mean(median_boot_samples))
# Out:
# Arithmetic Mean is : nan
# <ipython-input-50-bf8730d8d7c5>:1: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#   print("Arithmetic Mean is :", mean(median_boot_samples))

# %%
conf_int = np.percentile(median_boot_samples, [2.5, 97.5])
conf_int
# Out:
# array([nan, nan])

# %%
import seaborn as sns
sns.kdeplot(median_boot_samples)
for endpoint in conf_int:
  plt.axvline(endpoint, color = 'red')
